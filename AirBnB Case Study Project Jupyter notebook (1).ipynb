# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('AB_NYC_2019.csv')
air_bnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# How many neighborhood groups are available and which shows up the most?

groups= air_bnb.groupby('neighbourhood_group', as_index=False)
groups.count()[['neighbourhood_group', 'neighbourhood']].sort_values(['neighbourhood'], ascending=False)
# Out:
#   neighbourhood_group  neighbourhood
# 2           Manhattan          21661
# 1            Brooklyn          20104
# 3              Queens           5666
# 0               Bronx           1091
# 4       Staten Island            373

# %%
# Are private rooms the most popular in manhattan?
rooms=air_bnb.groupby(['neighbourhood_group', 'room_type'], as_index=True)
rooms[['id']].count()

#entire home/apt are the most popular in Manhattan
# Out:
#                                         id
# neighbourhood_group room_type
# Bronx               Entire home/apt    379
#                     Private room       652
#                     Shared room         60
# Brooklyn            Entire home/apt   9559
#                     Private room     10132
#                     Shared room        413
# Manhattan           Entire home/apt  13199
#                     Private room      7982
#                     Shared room        480
# Queens              Entire home/apt   2096
#                     Private room      3372
#                     Shared room        198
# Staten Island       Entire home/apt    176
#                     Private room       188
#                     Shared room          9

# %%
# Which hosts are the busiest and based on their reviews?
reviews = air_bnb.groupby('host_name',as_index=True)
reviews.count()[['reviews_per_month']].sort_values(['reviews_per_month'],ascending=False).head()
# Out:
#               reviews_per_month
# host_name
# Michael                     335
# David                       309
# John                        250
# Alex                        229
# Sonder (NYC)                207

# %%
#Which neighorhood group has the highest average price?
neighborhood_price = air_bnb.groupby('neighbourhood_group',as_index=True)

neighborhood_price.mean()[['price']].sort_values(['price'],ascending=False)
# Out:
#                           price
# neighbourhood_group
# Manhattan            196.875814
# Brooklyn             124.383207
# Staten Island        114.812332
# Queens                99.517649
# Bronx                 87.496792

# %%
# Which neighbor hood group has the highest total price?
neighborhood_price = air_bnb.groupby('neighbourhood_group',as_index=True)

neighborhood_price.sum()[['price']].sort_values(['price'],ascending=False)
# Out:
#                        price
# neighbourhood_group
# Manhattan            4264527
# Brooklyn             2500600
# Queens                563867
# Bronx                  95459
# Staten Island          42825

# %%
#Which top 5 hosts have the highest total price?
host = air_bnb.groupby('host_name',as_index=True)

host.sum()[['price']].sort_values(['price'],ascending=False).head()
# Out:
#               price
# host_name
# Sonder (NYC)  82795
# Blueground    70331
# Michael       66895
# David         65844
# Alex          52563

# %%
# Who currently has no (zero) availability with a review count of 100 or more?
availability = air_bnb[air_bnb['availability_365'] == 0][['id', 'availability_365' ,'number_of_reviews']]
reviews = air_bnb[air_bnb['number_of_reviews'] > 100][['id', 'availability_365' ,'number_of_reviews']]
joined = availability.merge(reviews, on = 'id', how='inner')
joined
# Out:
#            id  availability_365_x  number_of_reviews_x  availability_365_y  \
# 0        5203                   0                  118                   0
# 1       20913                   0                  168                   0
# 2       30031                   0                  193                   0
# 3       44221                   0                  114                   0
# 4       45556                   0                  206                   0
# ..        ...                 ...                  ...                 ...
# 153  22705516                   0                  103                   0
# 154  23574142                   0                  119                   0
# 155  24267706                   0                  102                   0
# 156  25719044                   0                  131                   0
# 157  27759146                   0                  112                   0
#
#      number_of_reviews_y
# 0                    118
# ...

# %%
# What host has the highest total of prices and where are they located?
host = air_bnb.groupby(['host_name','neighbourhood_group'],as_index=True)

host.sum()[['price']].sort_values(['price'],ascending=False).head()
# Out:
#                                   price
# host_name    neighbourhood_group
# Sonder (NYC) Manhattan            82795
# Blueground   Manhattan            69741
# Michael      Manhattan            42093
# David        Manhattan            40366
# Kara         Manhattan            35828

# %%
# When did Danielle from Queens last receive a review?
location = air_bnb[['host_name', 'last_review', 'neighbourhood_group']]

queens = location[location['neighbourhood_group'] == 'Queens']

danielle = queens[queens['host_name'] == 'Danielle'].sort_values('last_review', ascending=False)
danielle
# Out:
#       host_name last_review neighbourhood_group
# 22469  Danielle  2019-07-08              Queens
# 21517  Danielle  2019-07-07              Queens
# 20403  Danielle  2019-07-06              Queens
# 22068  Danielle  2019-07-06              Queens
# 7086   Danielle  2019-07-03              Queens
# 33861  Danielle  2019-06-20              Queens
# 27021  Danielle  2018-01-02              Queens
# 16349  Danielle         NaN              Queens

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
most_listings=air_bnb.groupby('host_name', as_index=True)
most_listings[['id']].count().sort_values(['id'], ascending=False).head()
# Out:
#                id
# host_name
# Michael       417
# David         403
# Sonder (NYC)  327
# John          294
# Alex          279

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
open_availability = air_bnb[air_bnb['availability_365'] == 365]['id'].count()
open_availability
# Out:
# 1295

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
room_reviews=air_bnb.groupby('room_type', as_index=True)
room_reviews[['number_of_reviews']].sum().sort_values(['number_of_reviews'], ascending=False)
# Out:
#                  number_of_reviews
# room_type
# Entire home/apt             580403
# Private room                538346
# Shared room                  19256

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --

# %%
#Manhattan and Brooklyn are the most popular neighborhoods while most people perfer entire home/apt and/or private room.
#Manhattan is the most exepnsive to live in.
